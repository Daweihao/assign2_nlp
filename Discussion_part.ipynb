# %%
import os
import csv
import subprocess
import re
import random
import numpy as np
from numpy import linalg as LA
import pandas as pd

# %%
def read_characters():
    tuples = []
    characters = {''}
    with open('will_play_text.csv') as f:
        csv_reader = csv.reader(f, delimiter=';')
        for row in csv_reader:
          charactor = row[4]
          characters.add(charactor)
          line = row[5]
          line_tokens = re.sub(r'[^a-zA-Z0-9\s]', ' ', line).split()
          line_tokens = [token.lower() for token in line_tokens]
          tuples.append((charactor, line_tokens))
    return tuples,characters

# %%
ctuples,charac = read_characters()

charac.discard('')
l_cha = list(charac)

# %%
len(l_cha)
# Out:
# 934

# %%
def read_in_shakespeare():
  '''Reads in the Shakespeare dataset processes it into a list of tuples.
     Also reads in the vocab and play name lists from files.

  Each tuple consists of
  tuple[0]: The name of the play
  tuple[1] A line from the play as a list of tokenized words.

  Returns:
    tuples: A list of tuples in the above format.
    document_names: A list of the plays present in the corpus.
    vocab: A list of all tokens in the vocabulary.
  '''

  tuples = []

  with open('will_play_text.csv') as f:
    csv_reader = csv.reader(f, delimiter=';')
    for row in csv_reader:
      play_name = row[1]
      line = row[5]
      line_tokens = re.sub(r'[^a-zA-Z0-9\s]', ' ', line).split()
      line_tokens = [token.lower() for token in line_tokens]

      tuples.append((play_name, line_tokens))

  with open('vocab.txt') as f:
    vocab =  [line.strip() for line in f]

  with open('play_names.txt') as f:
    document_names =  [line.strip() for line in f]

  return tuples, document_names, vocab

def get_row_vector(matrix, row_id):
  return matrix[row_id, :]

def get_column_vector(matrix, col_id):
  return matrix[:, col_id]

# %%
def create_term_character_matrix(line_tuples, characters, vocab):
    ''' Returns a numpy array containing the term character matrix for the input lines.
    '''
    vocab_to_id = dict(zip(vocab, range(0, len(vocab))))
    cha_to_id = dict(zip(characters,range(0,len(characters))))
    tdm = np.zeros(shape=(len(characters),len(vocab)))
    for line in line_tuples:
        cha = line[0]
        x_axis = cha_to_id.get(cha)
        if x_axis is None:
            continue
        for i in range(0,len(line[1])):
          y_axis = vocab_to_id.get(line[1][i])
          tdm[x_axis,y_axis] += 1
            
    return tdm

# %%
def compute_cosine_similarity(vector1, vector2):
  '''Computes the cosine similarity of the two input vectors.

  Inputs:
    vector1: A nx1 numpy array
    vector2: A nx1 numpy array

  Returns:
    A scalar similarity value.
  '''
  cs = np.dot(vector1,vector2)/(LA.norm(vector1)*LA.norm(vector2))
  # YOUR CODE HERE
  return cs

def compute_jaccard_similarity(vector1, vector2):
  '''Computes the cosine similarity of the two input vectors.

  Inputs:
    vector1: A nx1 numpy array
    vector2: A nx1 numpy array

  Returns:
    A scalar similarity value.
  '''
  
  # YOUR CODE HERE
  num = np.minimum(vector1,vector2)
  dom = np.maximum(vector1,vector2)
  js = np.sum(num)/np.sum(dom)

  return js
def compute_dice_similarity(vector1, vector2):
  '''Computes the cosine similarity of the two input vectors.

  Inputs:
    vector1: A nx1 numpy array
    vector2: A nx1 numpy array

  Returns:
    A scalar similarity value.
  '''

  # YOUR CODE HERE
  upper = np.minimum(vector1,vector2)
  upper_sum = np.sum(upper) * 2
  dom = np.sum(vector1 + vector2)
  return upper_sum/dom
def rank_cha(target_play_index, term_document_matrix, similarity_fn):
  ''' Ranks the similarity of all of the plays to the target play.

  Inputs:
    target_play_index: The integer index of the play we want to compare all others against.
    term_document_matrix: The term-document matrix as a mxn numpy array.
    similarity_fn: Function that should be used to compared vectors for two
      documents. Either compute_dice_similarity, compute_jaccard_similarity, or
      compute_cosine_similarity.

  Returns:
    A length-n list of integer indices corresponding to play names,
    ordered by decreasing similarity to the play indexed by target_play_index
  '''
  
  # YOUR CODE HERE
  nums = term_document_matrix.shape[0]
  target = term_document_matrix[target_play_index,:]
  docs_ranking = {}
  result = []
  for i in range(nums):
          if i!= target_play_index:
              similarity_doc = similarity_fn(term_document_matrix[i,:], target)
              docs_ranking[i] = similarity_doc
  sort_ranking = sorted(docs_ranking.items(),key=lambda item: item[1],reverse=True)
  for k,v in sort_ranking:
      result.append(k)
  return result

# %%
print('Computing term character matrix...')
tch_matrix = create_term_character_matrix(ctuples,l_cha,vocab)
# Out:
# Computing term character matrix...

# %%
len(tch_matrix)
# Out:
# 934

# %%
len(sum_for_row)
# Out:
# 934

# %%
sum_for_row = np.sum(tch_matrix,axis=1)
mask = []
for i in range(len(l_cha)):
    if sum_for_row[i]< 1100:
        mask.append(i)
masked_tc = np.delete(tch_matrix,mask,0)
masked_ch = np.delete(l_cha,mask)

# %%
len(masked)
# Out:
# 934

# %%
most1 = []
least1 = []
most2 = []
least2 = []
most3 = []
least3 = []
for idx in range(len(masked_ch)):
    ranks1 = rank_cha(idx,masked_tc,compute_cosine_similarity)
    most1.append(masked_ch[ranks1[0]])
    least1.append(masked_ch[ranks1[len(ranks1)-1]])
    ranks2 = rank_cha(idx,masked_tc,compute_dice_similarity)
    most2.append(masked_ch[ranks2[0]])
    least2.append(masked_ch[ranks2[len(ranks2)-1]])
    ranks3 = rank_cha(idx,masked_tc,compute_jaccard_similarity)
    most3.append(masked_ch[ranks3[0]])
    least3.append(masked_ch[ranks3[len(ranks3)-1]])

# %%
df = pd.DataFrame({'Character':masked_ch[0:len(masked_ch)],'Most_cosine':most1,'Least_cosine':least1,'M_dice':most2,'L_dice':least2,'M_jaccard':most3,'L_jaccard':least3})

# %% [markdown]
# ## Result

# %% [markdown]
# The result of the similarity between characters. Each column after first column is its corresponding Most or least similarity based on different method.

# %%
df
# Out:
#               Character      Most_cosine     Least_cosine             M_dice  \
# 0     HENRY BOLINGBROKE             YORK       SIR ANDREW          KING JOHN
# 1             CYMBELINE             KING          SLENDER              QUEEN
# 2        SIR HUGH EVANS         FLUELLEN           AEGEON   MISTRESS QUICKLY
# 3               BERTRAM           HELENA           Chorus           COUNTESS
# 4            HOLOFERNES  First Gentleman          SLENDER            COSTARD
# 5       DUCHESS OF YORK   QUEEN MARGARET             MOTH    QUEEN ELIZABETH
# 6               PROTEUS        VALENTINE       CANTERBURY          VALENTINE
# 7          LADY MACBETH          MACBETH          SLENDER          CYMBELINE
# 8       QUEEN KATHARINE  CARDINAL WOLSEY    First Citizen            BERTRAM
# 9             APEMANTUS            TIMON             MOTH               Fool
# 10    DROMIO OF EPHESUS             FORD       CANTERBURY         OF EPHESUS
# 11               TALBOT             YORK            SPEED  HENRY BOLINGBROKE
# 12                 DUKE         PERICLES             MOTH           COUNTESS
# 13              WARWICK             YORK          SLENDER               YORK
# 14           SIR ANDREW          SLENDER       CANTERBURY            SLENDER
# 15              CHARLES     KING HENRY V          SLENDER            RICHARD
# 16            LAUNCELOT            Clown           Chorus            COSTARD
# 17            PETRUCHIO          OTHELLO       CANTERBURY          CLEOPATRA
# 18     MISTRESS QUICKLY             IAGO           AEGEON      MISTRESS PAGE
# 19            CONSTANCE   QUEEN MARGARET             MOTH    DUCHESS OF YORK
# 20             MORTIMER             YORK       SIR ANDREW             EDWARD
# 21                PARIS       GLOUCESTER             MOTH              REGAN
# 22               TRANIO   DUKE VINCENTIO  Third Gentleman          HORTENSIO
# 23              FLAVIUS       GLOUCESTER          SLENDER           COUNTESS
# 24            HORTENSIO           GREMIO       CANTERBURY             TRANIO
# 25            THERSITES         FALSTAFF      KING PHILIP     SIR TOBY BELCH
# 26              TROILUS           HAMLET       SIR ANDREW   KING RICHARD III
# 27               HECTOR       GLOUCESTER             MOTH          SEBASTIAN
# 28              ADRIANA     DUKE OF YORK             MOTH       DUKE OF YORK
# 29                 MOTH            BIRON       SIR ANDREW            COSTARD
# ..                  ...              ...              ...                ...
# 216             SHYLOCK           PORTIA       CANTERBURY            ANTONIO
# 217             Provost   DUKE VINCENTIO           AEGEON            ESCALUS
# 218             LORENZO           HAMLET       SIR ANDREW           GRATIANO
# 219          ALCIBIADES       GLOUCESTER             MOTH           HASTINGS
# 220                IAGO          ANTONIO             MOTH            OTHELLO
# 221              ANTONY          CASSIUS       SIR ANDREW            CASSIUS
# 222       KING HENRY VI   QUEEN MARGARET       SIR ANDREW     QUEEN MARGARET
# 223      QUEEN MARGARET    KING HENRY VI          SLENDER      KING HENRY VI
# 224              JAQUES           PORTIA      KING PHILIP              CELIA
# 225           CLEOPATRA      MARK ANTONY             MOTH        MARK ANTONY
# 226                Lord          HOTSPUR          SLENDER              BOYET
# 227           FERDINAND           HAMLET             MOTH            ANTONIO
# 228            VOLUMNIA           BRUTUS          SLENDER               KING
# 229             MACDUFF          MACBETH          SLENDER             ALBANY
# 230             DUCHESS    KING HENRY VI             MOTH    DUCHESS OF YORK
# 231              EXETER          ULYSSES       SIR ANDREW     NORTHUMBERLAND
# 232             OTHELLO       GLOUCESTER             MOTH        MARK ANTONY
# 233           VALENTINE          PROTEUS       CANTERBURY            PROTEUS
# 234             ESCALUS   DUKE VINCENTIO           PISTOL           HERMIONE
# 235            HERMIONE           HELENA           Chorus           FLORIZEL
# 236             OPHELIA    LORD POLONIUS             MOTH            LAERTES
# 237           DESDEMONA           HELENA       CANTERBURY              VIOLA
# 238            BENEDICK         ROSALIND       CANTERBURY            ANTONIO
# 239              OLIVIA          ANTONIO       CANTERBURY              VIOLA
# 240           AUTOLYCUS            Clown      KING PHILIP              LAFEU
# 241              EDMUND       GLOUCESTER             MOTH               KENT
# 242       First Citizen         COMINIUS          SLENDER           SICINIUS
# 243  POSTHUMUS LEONATUS       CORIOLANUS        AGAMEMNON            IACHIMO
# 244   CARDINAL PANDULPH     KING HENRY V       SIR ANDREW        KING PHILIP
# 245        DUKE OF YORK       GLOUCESTER             MOTH    QUEEN ELIZABETH
#
#          L_dice          M_jaccard   L_jaccard
# 0    GLOUCESTER          KING JOHN  GLOUCESTER
# 1    GLOUCESTER              QUEEN  GLOUCESTER
# 2    GLOUCESTER   MISTRESS QUICKLY  GLOUCESTER
# 3    GLOUCESTER           COUNTESS  GLOUCESTER
# 4    GLOUCESTER            COSTARD  GLOUCESTER
# 5    GLOUCESTER    QUEEN ELIZABETH  GLOUCESTER
# 6    GLOUCESTER          VALENTINE  GLOUCESTER
# 7    GLOUCESTER          CYMBELINE  GLOUCESTER
# 8    GLOUCESTER            BERTRAM  GLOUCESTER
# 9    GLOUCESTER               Fool  GLOUCESTER
# 10   GLOUCESTER         OF EPHESUS  GLOUCESTER
# 11   GLOUCESTER  HENRY BOLINGBROKE  GLOUCESTER
# 12   GLOUCESTER           COUNTESS  GLOUCESTER
# 13         Host               YORK        Host
# 14   GLOUCESTER            SLENDER  GLOUCESTER
# 15   GLOUCESTER            RICHARD  GLOUCESTER
# 16   GLOUCESTER            COSTARD  GLOUCESTER
# 17     MORTIMER          CLEOPATRA    MORTIMER
# 18   GLOUCESTER      MISTRESS PAGE  GLOUCESTER
# 19   GLOUCESTER    DUCHESS OF YORK  GLOUCESTER
# 20   GLOUCESTER             EDWARD  GLOUCESTER
# 21   GLOUCESTER              REGAN  GLOUCESTER
# 22   GLOUCESTER          HORTENSIO  GLOUCESTER
# 23   GLOUCESTER           COUNTESS  GLOUCESTER
# 24   GLOUCESTER             TRANIO  GLOUCESTER
# 25   GLOUCESTER     SIR TOBY BELCH  GLOUCESTER
# 26       AEGEON   KING RICHARD III      AEGEON
# 27   GLOUCESTER          SEBASTIAN  GLOUCESTER
# 28   GLOUCESTER       DUKE OF YORK  GLOUCESTER
# 29   GLOUCESTER            COSTARD  GLOUCESTER
# ..          ...                ...         ...
# 216  GLOUCESTER            ANTONIO  GLOUCESTER
# 217  GLOUCESTER            ESCALUS  GLOUCESTER
# 218  GLOUCESTER           GRATIANO  GLOUCESTER
# 219  GLOUCESTER           HASTINGS  GLOUCESTER
# 220    MORTIMER            OTHELLO    MORTIMER
# 221  GLOUCESTER            CASSIUS  GLOUCESTER
# 222      AENEAS     QUEEN MARGARET      AENEAS
# 223      AENEAS      KING HENRY VI      AENEAS
# 224  GLOUCESTER              CELIA  GLOUCESTER
# 225    MORTIMER        MARK ANTONY    MORTIMER
# 226  GLOUCESTER              BOYET  GLOUCESTER
# 227        Host            ANTONIO        Host
# 228  GLOUCESTER               KING  GLOUCESTER
# 229  GLOUCESTER             ALBANY  GLOUCESTER
# 230  GLOUCESTER    DUCHESS OF YORK  GLOUCESTER
# 231  GLOUCESTER     NORTHUMBERLAND  GLOUCESTER
# 232      AEGEON        MARK ANTONY      AEGEON
# 233  GLOUCESTER            PROTEUS  GLOUCESTER
# 234  GLOUCESTER           HERMIONE  GLOUCESTER
# 235  GLOUCESTER           FLORIZEL  GLOUCESTER
# 236  GLOUCESTER            LAERTES  GLOUCESTER
# 237  GLOUCESTER              VIOLA  GLOUCESTER
# 238      AEGEON            ANTONIO      AEGEON
# 239  GLOUCESTER              VIOLA  GLOUCESTER
# 240  GLOUCESTER              LAFEU  GLOUCESTER
# 241  GLOUCESTER               KENT  GLOUCESTER
# 242  GLOUCESTER           SICINIUS  GLOUCESTER
# 243        Host            IACHIMO        Host
# 244  GLOUCESTER        KING PHILIP  GLOUCESTER
# 245  GLOUCESTER    QUEEN ELIZABETH  GLOUCESTER
#
# [246 rows x 7 columns]
